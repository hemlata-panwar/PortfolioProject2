# %%
# import some important library 
import pandas as pd

# %%
#    Dataset is available as csv file (now we are providing file path)    #
data=pd.read_csv(r'C:\Users\Micro\Downloads\weather3.csv')

# %%
data
# Out:
#        Precipitation      Date  Month  Week   Year        City Code  \
# 0               0.00  1/3/2016      1      3  2016  Birmingham  BHM
# 1               0.00  1/3/2016      1      3  2016  Huntsville  HSV
# 2               0.16  1/3/2016      1      3  2016      Mobile  MOB
# 3               0.00  1/3/2016      1      3  2016  Montgomery  MGM
# 4               0.01  1/3/2016      1      3  2016   Anchorage  ANC
# ...              ...       ...    ...    ...   ...         ...  ...
# 16738           0.08  1/1/2017      1      1  2017      Casper  CPR
# 16739           0.00  1/1/2017      1      1  2017    Cheyenne  CYS
# 16740           0.00  1/1/2017      1      1  2017      Lander  LND
# 16741           0.06  1/1/2017      1      1  2017     Rawlins  RWL
# 16742           0.10  1/1/2017      1      1  2017    Sheridan  SHR
#
#              Location    State  Temperature_Avg  Temperature_Max   \
# 0      Birmingham, AL  Alabama               39                46
# ...

# %% [markdown]
# #  .head ()
#  It shows N number of row in data(by defalult,N=5)

# %%
data.head(10)
# Out:
#    Precipitation      Date  Month  Week   Year        City Code  \
# 0           0.00  1/3/2016      1      3  2016  Birmingham  BHM
# 1           0.00  1/3/2016      1      3  2016  Huntsville  HSV
# 2           0.16  1/3/2016      1      3  2016      Mobile  MOB
# 3           0.00  1/3/2016      1      3  2016  Montgomery  MGM
# 4           0.01  1/3/2016      1      3  2016   Anchorage  ANC
# 5           0.09  1/3/2016      1      3  2016     Annette  ANN
# 6           0.05  1/3/2016      1      3  2016      Bethel  BET
# 7           0.15  1/3/2016      1      3  2016     Bettles  BTT
# 8           0.60  1/3/2016      1      3  2016    Cold Bay  CDB
# 9           2.15  1/3/2016      1      3  2016     Cordova  CDV
#
#          Location    State  Temperature_Avg  Temperature_Max   \
# 0  Birmingham, AL  Alabama               39                46
# 1  Huntsville, AL  Alabama               39                47
# 2      Mobile, AL  Alabama               46                51
# ...

# %% [markdown]
# #  .shape
# It shows number of rows and number of column in dataframe

# %%
data.shape
# Out:
# (16743, 14)

# %% [markdown]
# # .index
# This attribute provides index of dataframe

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16743, step=1)

# %% [markdown]
# # .dtypes
# it describes data type of each column

# %%
data.dtypes
# Out:
# Precipitation       float64
# Date                 object
# Month                 int64
# Week                  int64
# Year                  int64
# City                 object
# Code                 object
# Location             object
# State                object
# Temperature_Avg       int64
# Temperature_Max       int64
# Temperature_Min       int64
# Wind_Direction        int64
# Wind_Speed          float64
# dtype: object

# %% [markdown]
# #  .unique
# In a column,it shows all unique values,applied on a single column only.

# %%
data['Location'].unique()
# Out:
# array(['Birmingham, AL', 'Huntsville, AL', 'Mobile, AL', 'Montgomery, AL',
#        'Anchorage, AK', 'Annette, AK', 'Bethel, AK', 'Bettles, AK',
#        'Cold Bay, AK', 'Cordova, AK', 'Delta Junction/Ft Greely, AK',
#        'Fairbanks, AK', 'Gulkana, AK', 'Homer, AK', 'Iliamna, AK',
#        'Juneau, AK', 'Kenai, AK', 'Ketchikan, AK', 'King Salmon, AK',
#        'Kodiak, AK', 'Kotzebue, AK', 'Mc Grath, AK', 'Nome, AK',
#        'Northway, AK', 'Palmer, AK', 'Petersburg, AK',
#        'Puntilla Lake, AK', 'Shemya, AK', 'Sitka, AK', 'Skagway, AK',
#        'St Paul Island, AK', 'Talkeetna, AK', 'Tanana, AK',
#        'Utqiagvik (Barrow), AK', 'Yakutat, AK', 'Douglas Bisbee, AZ',
#        'Kingman, AZ', 'Phoenix, AZ', 'Tucson, AZ', 'Winslow, AZ',
#        'Fort Smith, AR', 'Harrison, AR', 'North Little Rock, AR',
#        'Bakersfield, CA', 'Bishop, CA', 'China Lake, CA', 'Concord, CA',
#        'Eureka, CA', 'Fresno, CA', 'Hayward, CA', 'Long Beach, CA',
# ...

# %% [markdown]
# #  .nunique
# It shows the total number of unique values in each column,it can applied on both single column and dataframe.

# %%
data.nunique()
# Out:
# Precipitation        565
# Date                  53
# Month                 12
# Week                  31
# Year                   2
# City                 307
# Code                 318
# Location             318
# State                 53
# Temperature_Avg      119
# Temperature_Max      125
# Temperature_Min      114
# Wind_Direction        37
# Wind_Speed          1461
# dtype: int64

# %% [markdown]
# # .count
# It shows total number of non-null in each column.It can be applied on a single column as well as on whole dataframe.

# %%
data.count()
# Out:
# Precipitation       16743
# Date                16743
# Month               16743
# Week                16743
# Year                16743
# City                16743
# Code                16743
# Location            16743
# State               16743
# Temperature_Avg     16743
# Temperature_Max     16743
# Temperature_Min     16743
# Wind_Direction      16743
# Wind_Speed          16743
# dtype: int64

# %% [markdown]
# # .value_counts
# in a column,it shows all unique values with their count but applied only on single column.

# %%
data['State'].value_counts()
# Out:
# Alaska            1719
# Texas             1272
# California         999
# Florida            636
# Montana            583
# Michigan           477
# Nebraska           424
# New York           424
# Oregon             424
# Tennessee          420
# Pennsylvania       371
# Mississippi        371
# Ohio               371
# North Carolina     371
# Washington         371
# Missouri           371
# Georgia            318
# Illinois           318
# Kansas             318
# Nevada             318
# Colorado           318
# Virginia           318
# South Dakota       265
# North Dakota       265
# Wyoming            265
# Minnesota          265
# Arizona            265
# Hawaii             265
# Kentucky           265
# Iowa               265
# Louisiana          261
# Oklahoma           212
# Wisconsin          212
# West Virginia      212
# South Carolina     212
# Alabama            212
# Indiana            212
# Idaho              159
# New Mexico         159
# Maine              159
# ...

# %% [markdown]
# # .info
# provides basic information about dataframe.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16743 entries, 0 to 16742
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Precipitation     16743 non-null  float64
#  1   Date              16743 non-null  object
#  2   Month             16743 non-null  int64
#  3   Week              16743 non-null  int64
#  4   Year              16743 non-null  int64
#  5   City              16743 non-null  object
#  6   Code              16743 non-null  object
#  7   Location          16743 non-null  object
#  8   State             16743 non-null  object
#  9   Temperature_Avg   16743 non-null  int64
#  10  Temperature_Max   16743 non-null  int64
#  11  Temperature_Min   16743 non-null  int64
#  12  Wind_Direction    16743 non-null  int64
#  13  Wind_Speed        16743 non-null  float64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# # Q.1) Find all the unique "wind speed" values in data?

# %%
data.head(5)
# Out:
#    Precipitation      Date  Month  Week   Year        City Code  \
# 0           0.00  1/3/2016      1      3  2016  Birmingham  BHM
# 1           0.00  1/3/2016      1      3  2016  Huntsville  HSV
# 2           0.16  1/3/2016      1      3  2016      Mobile  MOB
# 3           0.00  1/3/2016      1      3  2016  Montgomery  MGM
# 4           0.01  1/3/2016      1      3  2016   Anchorage  ANC
#
#          Location    State  Temperature_Avg  Temperature_Max   \
# 0  Birmingham, AL  Alabama               39                46
# 1  Huntsville, AL  Alabama               39                47
# 2      Mobile, AL  Alabama               46                51
# 3  Montgomery, AL  Alabama               45                52
# 4   Anchorage, AK   Alaska               34                38
#
#    Temperature_Min  Wind_Direction  Wind_Speed
# 0               32              33        4.33
# 1               31              32        3.86
# 2               41              35        9.73
# ...

# %%
data.nunique()
# Out:
# Precipitation        565
# Date                  53
# Month                 12
# Week                  31
# Year                   2
# City                 307
# Code                 318
# Location             318
# State                 53
# Temperature_Avg      119
# Temperature_Max      125
# Temperature_Min      114
# Wind_Direction        37
# Wind_Speed          1461
# dtype: int64

# %%
data['Wind_Speed'].nunique()
# Out:
# 1461

# %%
data['Wind_Speed'].unique()
# Out:
# array([ 4.33,  3.86,  9.73, ..., 12.53, 19.98, 18.16])

# %% [markdown]
# #  Q.2)  Find the number of times when the location is "Anchorage, AK"	?

# %%
data.head(5)
# Out:
#    Precipitation      Date  Month  Week   Year        City Code  \
# 0           0.00  1/3/2016      1      3  2016  Birmingham  BHM
# 1           0.00  1/3/2016      1      3  2016  Huntsville  HSV
# 2           0.16  1/3/2016      1      3  2016      Mobile  MOB
# 3           0.00  1/3/2016      1      3  2016  Montgomery  MGM
# 4           0.01  1/3/2016      1      3  2016   Anchorage  ANC
#
#          Location    State  Temperature_Avg  Temperature_Max   \
# 0  Birmingham, AL  Alabama               39                46
# 1  Huntsville, AL  Alabama               39                47
# 2      Mobile, AL  Alabama               46                51
# 3  Montgomery, AL  Alabama               45                52
# 4   Anchorage, AK   Alaska               34                38
#
#    Temperature_Min  Wind_Direction  Wind_Speed
# 0               32              33        4.33
# 1               31              32        3.86
# 2               41              35        9.73
# ...

# %%
#value_counts
data['City'].value_counts()
# Out:
# Norfolk           106
# Jackson           106
# Springfield       106
# Charleston        106
# Newark            106
#                  ...
# Milton             47
# Mt. Washington     47
# China Lake         45
# Wrangell           30
# Unalakleet          5
# Name: City, Length: 307, dtype: int64

# %%
#filtering data
#data.head(3)
data[data.Location == 'Anchorage, AK']
# Out:
#        Precipitation        Date  Month  Week   Year       City Code  \
# 4               0.01    1/3/2016      1      3  2016  Anchorage  ANC
# 319             0.00   1/10/2016      1     10  2016  Anchorage  ANC
# 634             0.15   1/17/2016      1     17  2016  Anchorage  ANC
# 949             0.00   1/24/2016      1     24  2016  Anchorage  ANC
# 1264            0.12   1/31/2016      1     31  2016  Anchorage  ANC
# 1579            0.08    2/7/2016      2      7  2016  Anchorage  ANC
# 1894            0.01   2/14/2016      2     14  2016  Anchorage  ANC
# 2209            0.23   2/21/2016      2     21  2016  Anchorage  ANC
# 2524            0.00   2/28/2016      2     28  2016  Anchorage  ANC
# 2839            0.04    3/6/2016      3      6  2016  Anchorage  ANC
# 3156            0.00   3/13/2016      3     13  2016  Anchorage  ANC
# 3471            0.61   3/20/2016      3     20  2016  Anchorage  ANC
# 3786            0.16   3/27/2016      3     27  2016  Anchorage  ANC
# ...

# %%
#groupby()
#data.head(2)
data.groupby('Location').get_group('Anchorage, AK')
# Out:
#        Precipitation        Date  Month  Week   Year       City Code  \
# 4               0.01    1/3/2016      1      3  2016  Anchorage  ANC
# 319             0.00   1/10/2016      1     10  2016  Anchorage  ANC
# 634             0.15   1/17/2016      1     17  2016  Anchorage  ANC
# 949             0.00   1/24/2016      1     24  2016  Anchorage  ANC
# 1264            0.12   1/31/2016      1     31  2016  Anchorage  ANC
# 1579            0.08    2/7/2016      2      7  2016  Anchorage  ANC
# 1894            0.01   2/14/2016      2     14  2016  Anchorage  ANC
# 2209            0.23   2/21/2016      2     21  2016  Anchorage  ANC
# 2524            0.00   2/28/2016      2     28  2016  Anchorage  ANC
# 2839            0.04    3/6/2016      3      6  2016  Anchorage  ANC
# 3156            0.00   3/13/2016      3     13  2016  Anchorage  ANC
# 3471            0.61   3/20/2016      3     20  2016  Anchorage  ANC
# 3786            0.16   3/27/2016      3     27  2016  Anchorage  ANC
# ...

# %% [markdown]
# # Q.3) Find the number of times when the 'wind speed was exactly 4km/h'.

# %%
data.head(2)
# Out:
#    Precipitation      Date  Month  Week   Year        City Code  \
# 0            0.0  1/3/2016      1      3  2016  Birmingham  BHM
# 1            0.0  1/3/2016      1      3  2016  Huntsville  HSV
#
#          Location    State  Temperature_Avg  Temperature_Max   \
# 0  Birmingham, AL  Alabama               39                46
# 1  Huntsville, AL  Alabama               39                47
#
#    Temperature_Min  Wind_Direction  Wind_Speed
# 0               32              33        4.33
# 1               31              32        3.86

# %%
data[data['Wind_Speed'] == 4 ]
# Out:
#        Precipitation        Date  Month  Week   Year            City Code  \
# 232             0.01    1/3/2016      1      3  2016       Pendleton  PDT
# 531             0.05   1/10/2016      1     10  2016       Williston  ISN
# 1155            0.96   1/24/2016      1     24  2016  Raleigh/Durham  RDU
# 2572            0.06   2/28/2016      2     28  2016       Red Bluff  RBL
# 2648            1.68   2/28/2016      2     28  2016         Slidell  ASD
# 4331            0.00    4/3/2016      4      3  2016       Pendleton  PDT
# 5307            0.22   4/24/2016      4     24  2016       Nashville  BNA
# 5515            0.00    5/1/2016      5      1  2016      Greenville  GLH
# 6000            0.10   5/15/2016      5     15  2016       Anchorage  ANC
# 6297            0.04   5/15/2016      5     15  2016         Seattle  SEA
# 6335            0.56   5/22/2016      5     22  2016        Mc Grath  MCG
# 6820            0.02   5/29/2016      5     29  2016            Reno  RNO
# ...

# %% [markdown]
# #  Q.4)  Find out all the null values in the data?

# %%
data.isnull().sum()
# Out:
# Precipitation       0
# Date                0
# Month               0
# Week                0
# Year                0
# City                0
# Code                0
# Location            0
# State               0
# Temperature_Avg     0
# Temperature_Max     0
# Temperature_Min     0
# Wind_Direction      0
# Wind_Speed          0
# dtype: int64

# %% [markdown]
# #  Q.5) Rename the column name "location" of the dataframe to "station_location".

# %%
# data.rename
data.rename(columns={'Location' : 'Station_Location'},inplace= True)

# %%
data.head()
# Out:
#    Precipitation      Date  Month  Week   Year        City Code  \
# 0           0.00  1/3/2016      1      3  2016  Birmingham  BHM
# 1           0.00  1/3/2016      1      3  2016  Huntsville  HSV
# 2           0.16  1/3/2016      1      3  2016      Mobile  MOB
# 3           0.00  1/3/2016      1      3  2016  Montgomery  MGM
# 4           0.01  1/3/2016      1      3  2016   Anchorage  ANC
#
#   Station_Location    State  Temperature_Avg  Temperature_Max   \
# 0   Birmingham, AL  Alabama               39                46
# 1   Huntsville, AL  Alabama               39                47
# 2       Mobile, AL  Alabama               46                51
# 3   Montgomery, AL  Alabama               45                52
# 4    Anchorage, AK   Alaska               34                38
#
#    Temperature_Min  Wind_Direction  Wind_Speed
# 0               32              33        4.33
# 1               31              32        3.86
# 2               41              35        9.73
# ...

# %% [markdown]
# # Q.6) What is the mean "Temperature_Min" ?

# %%
data.head(50)
# Out:
#     Precipitation      Date  Month  Week   Year                      City  \
# 0            0.00  1/3/2016      1      3  2016                Birmingham
# 1            0.00  1/3/2016      1      3  2016                Huntsville
# 2            0.16  1/3/2016      1      3  2016                    Mobile
# 3            0.00  1/3/2016      1      3  2016                Montgomery
# 4            0.01  1/3/2016      1      3  2016                 Anchorage
# 5            0.09  1/3/2016      1      3  2016                   Annette
# 6            0.05  1/3/2016      1      3  2016                    Bethel
# 7            0.15  1/3/2016      1      3  2016                   Bettles
# 8            0.60  1/3/2016      1      3  2016                  Cold Bay
# 9            2.15  1/3/2016      1      3  2016                   Cordova
# 10           0.00  1/3/2016      1      3  2016  Delta Junction/Ft Greely
# 11           0.00  1/3/2016      1      3  2016                 Fairbanks
# ...

# %%
data.Temperature_Min.mean()
# Out:
# 45.642716359075436

# %% [markdown]
# # Q.7)What is the standard deviation of "precipitation" variation?

# %%
data.Precipitation.std()
# Out:
# 0.988057158956622

# %% [markdown]
# # Q.8) Find top 20 and bottom 15  instances where "california" was state?

# %%
#value_counts()
data['State'].value_counts()
# Out:
# Alaska            1719
# Texas             1272
# California         999
# Florida            636
# Montana            583
# Michigan           477
# Nebraska           424
# New York           424
# Oregon             424
# Tennessee          420
# Pennsylvania       371
# Mississippi        371
# Ohio               371
# North Carolina     371
# Washington         371
# Missouri           371
# Georgia            318
# Illinois           318
# Kansas             318
# Nevada             318
# Colorado           318
# Virginia           318
# South Dakota       265
# North Dakota       265
# Wyoming            265
# Minnesota          265
# Arizona            265
# Hawaii             265
# Kentucky           265
# Iowa               265
# Louisiana          261
# Oklahoma           212
# Wisconsin          212
# West Virginia      212
# South Carolina     212
# Alabama            212
# Indiana            212
# Idaho              159
# New Mexico         159
# Maine              159
# ...

# %%
#filtering
data[data['State']=='California'].head(20)
# Out:
#      Precipitation       Date  Month  Week   Year           City Code  \
# 43            0.00   1/3/2016      1      3  2016    Bakersfield  BFL
# 44            0.00   1/3/2016      1      3  2016         Bishop  BIH
# 45            0.00   1/3/2016      1      3  2016     China Lake  NID
# 46            0.00   1/3/2016      1      3  2016        Concord  CCR
# 47            0.06   1/3/2016      1      3  2016         Eureka  EKA
# 48            0.00   1/3/2016      1      3  2016         Fresno  FAT
# 49            0.00   1/3/2016      1      3  2016        Hayward  HWD
# 50            0.00   1/3/2016      1      3  2016     Long Beach  LGB
# 51            0.00   1/3/2016      1      3  2016    Los Angeles  LAX
# 52            0.00   1/3/2016      1      3  2016      Red Bluff  RBL
# 53            0.00   1/3/2016      1      3  2016        Redding  RDD
# 54            0.00   1/3/2016      1      3  2016     Sacramento  SAC
# ...

# %%
data[data['State']=='California'].tail(15)
# Out:
#        Precipitation      Date  Month  Week   Year           City Code  \
# 16475           0.02  1/1/2017      1      1  2017         Eureka  EKA
# 16476           0.09  1/1/2017      1      1  2017         Fresno  FAT
# 16477           0.00  1/1/2017      1      1  2017        Hayward  HWD
# 16478           0.50  1/1/2017      1      1  2017     Long Beach  LGB
# 16479           0.27  1/1/2017      1      1  2017    Los Angeles  LAX
# 16480           0.00  1/1/2017      1      1  2017      Red Bluff  RBL
# 16481           0.00  1/1/2017      1      1  2017        Redding  RDD
# 16482           0.01  1/1/2017      1      1  2017     Sacramento  SAC
# 16483           0.00  1/1/2017      1      1  2017        Salinas  SNS
# 16484           1.19  1/1/2017      1      1  2017      San Diego  SAN
# 16485           0.00  1/1/2017      1      1  2017  San Francisco  SFO
# 16486           0.92  1/1/2017      1      1  2017       Sandberg  SDB
# ...

# %% [markdown]
# # Q.9) Find all intances when 'wind speed is above 24' and average Temperature is 44.?

# %%
data.head(5)
# Out:
#    Precipitation      Date  Month  Week   Year        City Code  \
# 0           0.00  1/3/2016      1      3  2016  Birmingham  BHM
# 1           0.00  1/3/2016      1      3  2016  Huntsville  HSV
# 2           0.16  1/3/2016      1      3  2016      Mobile  MOB
# 3           0.00  1/3/2016      1      3  2016  Montgomery  MGM
# 4           0.01  1/3/2016      1      3  2016   Anchorage  ANC
#
#   Station_Location    State  Temperature_Avg  Temperature_Max   \
# 0   Birmingham, AL  Alabama               39                46
# 1   Huntsville, AL  Alabama               39                47
# 2       Mobile, AL  Alabama               46                51
# 3   Montgomery, AL  Alabama               45                52
# 4    Anchorage, AK   Alaska               34                38
#
#    Temperature_Min  Wind_Direction  Wind_Speed
# 0               32              33        4.33
# 1               31              32        3.86
# 2               41              35        9.73
# ...

# %%
data[(data['Wind_Speed']>8) & (data['Temperature_Avg'] ==44)]
# Out:
#        Precipitation        Date  Month  Week   Year               City Code  \
# 605             0.11   1/10/2016      1     10  2016            Norfolk  ORF
# 658             1.66   1/17/2016      1     17  2016              Sitka  SIT
# 1224            0.00   1/24/2016      1     24  2016            Lubbock  LBB
# 1382            0.04   1/31/2016      1     31  2016         Louisville  SDF
# 1422            0.00   1/31/2016      1     31  2016        Springfield  SGF
# ...              ...         ...    ...    ...   ...                ...  ...
# 15228           0.04   12/4/2016     12      4  2016         Bridgeport  BDR
# 15402           0.17   12/4/2016     12      4  2016       Williamsport  IPT
# 15459           0.63   12/4/2016     12      4  2016            Seattle  SEA
# 15750           0.15  12/11/2016     12     11  2016  Dallas-Fort Worth  DFW
# 16067           0.00  12/18/2016     12     18  2016  Dallas-Fort Worth  DFW
#
# ...

# %% [markdown]
# # Q.10) What is the mean value of each column against each 'State'?

# %%
data.head(4)
# Out:
#    Precipitation      Date  Month  Week   Year        City Code  \
# 0           0.00  1/3/2016      1      3  2016  Birmingham  BHM
# 1           0.00  1/3/2016      1      3  2016  Huntsville  HSV
# 2           0.16  1/3/2016      1      3  2016      Mobile  MOB
# 3           0.00  1/3/2016      1      3  2016  Montgomery  MGM
#
#   Station_Location    State  Temperature_Avg  Temperature_Max   \
# 0   Birmingham, AL  Alabama               39                46
# 1   Huntsville, AL  Alabama               39                47
# 2       Mobile, AL  Alabama               46                51
# 3   Montgomery, AL  Alabama               45                52
#
#    Temperature_Min  Wind_Direction  Wind_Speed
# 0               32              33        4.33
# 1               31              32        3.86
# 2               41              35        9.73
# 3               38              32        6.86

# %%
#groupby function
data.groupby('State').mean()
# Out:
#                 Precipitation     Month      Week          Year  \
# State
# Alabama              0.776179  6.339623  15.660377  2016.018868
# Alaska               0.566126  6.392670  15.603839  2016.019779
# Arizona              0.162566  6.339623  15.660377  2016.018868
# Arkansas             0.603711  6.339623  15.660377  2016.018868
# California           0.323774  6.308308  15.666667  2016.018018
# Colorado             0.182987  6.339623  15.660377  2016.018868
# Connecticut          0.587830  6.339623  15.660377  2016.018868
# DE                   0.632453  6.339623  15.660377  2016.018868
# Delaware             0.632453  6.339623  15.660377  2016.018868
# Florida              0.891006  6.339623  15.660377  2016.018868
# Georgia              0.712799  6.339623  15.660377  2016.018868
# Hawaii               0.664868  6.339623  15.660377  2016.018868
# Idaho                0.238113  6.339623  15.660377  2016.018868
# ...

# %% [markdown]
# # Q.11) What is the minimum & maximum value of each column against each 'State'?

# %%
data.head(2)
# Out:
#    Precipitation      Date  Month  Week   Year        City Code  \
# 0            0.0  1/3/2016      1      3  2016  Birmingham  BHM
# 1            0.0  1/3/2016      1      3  2016  Huntsville  HSV
#
#   Station_Location    State  Temperature_Avg  Temperature_Max   \
# 0   Birmingham, AL  Alabama               39                46
# 1   Huntsville, AL  Alabama               39                47
#
#    Temperature_Min  Wind_Direction  Wind_Speed
# 0               32              33        4.33
# 1               31              32        3.86

# %%
#group by min values of each state
(data.groupby('State').min())
# Out:
#                 Precipitation      Date  Month  Week   Year  \
# State
# Alabama                  0.00  1/1/2017      1      1  2016
# Alaska                   0.00  1/1/2017      1      1  2016
# Arizona                  0.00  1/1/2017      1      1  2016
# Arkansas                 0.00  1/1/2017      1      1  2016
# California               0.00  1/1/2017      1      1  2016
# Colorado                 0.00  1/1/2017      1      1  2016
# Connecticut              0.00  1/1/2017      1      1  2016
# DE                       0.00  1/1/2017      1      1  2016
# Delaware                 0.00  1/1/2017      1      1  2016
# Florida                  0.00  1/1/2017      1      1  2016
# Georgia                  0.00  1/1/2017      1      1  2016
# Hawaii                   0.00  1/1/2017      1      1  2016
# Idaho                    0.00  1/1/2017      1      1  2016
# Illinois                 0.00  1/1/2017      1      1  2016
# ...

# %%
#group by the maximum values of each state
data.groupby('State').max()
# Out:
#                 Precipitation      Date  Month  Week   Year  \
# State
# Alabama                  4.44  9/4/2016     12     31  2017
# Alaska                  10.34  9/4/2016     12     31  2017
# Arizona                  2.28  9/4/2016     12     31  2017
# Arkansas                 6.08  9/4/2016     12     31  2017
# California               6.60  9/4/2016     12     31  2017
# Colorado                 1.82  9/4/2016     12     31  2017
# Connecticut              2.81  9/4/2016     12     31  2017
# DE                       3.27  9/4/2016     12     31  2017
# Delaware                 3.27  9/4/2016     12     31  2017
# Florida                 15.19  9/4/2016     12     31  2017
# Georgia                 11.52  9/4/2016     12     31  2017
# Hawaii                  14.03  9/4/2016     12     31  2017
# Idaho                    1.74  9/4/2016     12     31  2017
# Illinois                 5.59  9/4/2016     12     31  2017
# ...

# %% [markdown]
# # Q.12) Find all the records where state is maine?

# %%
data[data['State']== 'Maine']
# Out:
#        Precipitation        Date  Month  Week   Year      City Code  \
# 129             0.00    1/3/2016      1      3  2016    Bangor  BGR
# 130             0.10    1/3/2016      1      3  2016   Caribou  CAR
# 131             0.01    1/3/2016      1      3  2016  Portland  PWM
# 444             1.99   1/10/2016      1     10  2016    Bangor  BGR
# 445             0.52   1/10/2016      1     10  2016   Caribou  CAR
# ...              ...         ...    ...    ...   ...       ...  ...
# 16241           0.10  12/25/2016     12     25  2016   Caribou  CAR
# 16242           0.22  12/25/2016     12     25  2016  Portland  PWM
# 16557           1.73    1/1/2017      1      1  2017    Bangor  BGR
# 16558           1.89    1/1/2017      1      1  2017   Caribou  CAR
# 16559           2.10    1/1/2017      1      1  2017  Portland  PWM
#
#       Station_Location  State  Temperature_Avg  Temperature_Max   \
# 129         Bangor, ME  Maine               29                35
# ...

# %% [markdown]
# # Q.13) Find all instances when 'State is VA' or 'wind speed' is above 44?

# %%
#data[(data['State']=='VA') | (data['Wind_Speed']> 44 )].tail(20)
#data[(data['State']=='VA') | (data['Wind_Speed']> 44 )].head(30)
data[(data['State']=='VA') | (data['Wind_Speed']> 44 )]
# Out:
#        Precipitation        Date  Month  Week   Year            City Code  \
# 191             0.00    1/3/2016      1      3  2016  Mt. Washington  MWN
# 287             0.00    1/3/2016      1      3  2016      Blacksburg  BCB
# 602             0.90   1/10/2016      1     10  2016      Blacksburg  BCB
# 917             0.50   1/17/2016      1     17  2016      Blacksburg  BCB
# 1232            1.59   1/24/2016      1     24  2016      Blacksburg  BCB
# 1547            0.00   1/31/2016      1     31  2016      Blacksburg  BCB
# 1766            0.00    2/7/2016      2      7  2016  Mt. Washington  MWN
# 1862            1.23    2/7/2016      2      7  2016      Blacksburg  BCB
# 2177            0.12   2/14/2016      2     14  2016      Blacksburg  BCB
# 2492            2.48   2/21/2016      2     21  2016      Blacksburg  BCB
# 2807            1.41   2/28/2016      2     28  2016      Blacksburg  BCB
# 3028            0.00    3/6/2016      3      6  2016  Mt. Washington  MWN
# ...

# %% [markdown]
# # Q.15) Find all instances
#     when:
#     1.State is new york and precipitation is greater than 0.48
#     or
#     wind direction is above 25

# %%
data.head(6)
# Out:
#    Precipitation      Date  Month  Week   Year        City Code  \
# 0           0.00  1/3/2016      1      3  2016  Birmingham  BHM
# 1           0.00  1/3/2016      1      3  2016  Huntsville  HSV
# 2           0.16  1/3/2016      1      3  2016      Mobile  MOB
# 3           0.00  1/3/2016      1      3  2016  Montgomery  MGM
# 4           0.01  1/3/2016      1      3  2016   Anchorage  ANC
# 5           0.09  1/3/2016      1      3  2016     Annette  ANN
#
#   Station_Location    State  Temperature_Avg  Temperature_Max   \
# 0   Birmingham, AL  Alabama               39                46
# 1   Huntsville, AL  Alabama               39                47
# 2       Mobile, AL  Alabama               46                51
# 3   Montgomery, AL  Alabama               45                52
# 4    Anchorage, AK   Alaska               34                38
# 5      Annette, AK   Alaska               38                44
#
#    Temperature_Min  Wind_Direction  Wind_Speed
# ...

# %%
data[(data['State'] == 'New York') & (data['Precipitation'] > 0.48) | (data['Wind_Direction'] >25)]
# Out:
#        Precipitation      Date  Month  Week   Year            City Code  \
# 0               0.00  1/3/2016      1      3  2016      Birmingham  BHM
# 1               0.00  1/3/2016      1      3  2016      Huntsville  HSV
# 2               0.16  1/3/2016      1      3  2016          Mobile  MOB
# 3               0.00  1/3/2016      1      3  2016      Montgomery  MGM
# 39              0.00  1/3/2016      1      3  2016         Winslow  INW
# ...              ...       ...    ...    ...   ...             ...  ...
# 16713           0.00  1/1/2017      1      1  2017   Wichita Falls  SPS
# 16714           0.00  1/1/2017      1      1  2017  Salt Lake City  SLC
# 16729           0.01  1/1/2017      1      1  2017          Yakima  YKM
# 16739           0.00  1/1/2017      1      1  2017        Cheyenne  CYS
# 16740           0.00  1/1/2017      1      1  2017          Lander  LND
#
#          Station_Location       State  Temperature_Avg  Temperature_Max   \
# ...
